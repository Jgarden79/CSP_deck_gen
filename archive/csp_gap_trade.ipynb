# %%
import gap_trade_custom as gap
import importlib
importlib.reload(gap)
# Out:
# <module 'gap_trade_custom' from 'C:\\Users\\mreis\\OneDrive - Lido Advisors, LLC\\Concentrated Stock\\Lido CSP\\gap_trade_custom.py'>

# %%
trade = gap.GapTrade(RIC='TSLA.O',get_data='n',expiry='2025-06-20',gap=5,prot=20,exclude_div='y',custom_div='n')
trade.calc_trade(output='line')
# Out:
#   Underlying Asset  Asset Price  Minimum ($) Expiration Date  Months Left  \
# 0             TSLA       183.01      18300.0      2025-06-20         12.0
#
#   Potential Upside (%) Annual Potential Upside (%)  \
# 0               53.00%                      53.14%
#
#   Downside Before Protection (%) Protection (%) Annual Protection (%)  \
# 0                          4.38%         19.12%                19.18%
#
#   Spread (%) Trade Cost (%) Collateral
# 0     72.12%         -0.26%       TSLA

# %%
trade.calc_trade(output='trades')
# Out:
#      Trans              Symbol STRIKE_PRC     MID
# 2433   SCO  TSLA2025-06-20C280      280.0  14.625
# 2400   BPO  TSLA2025-06-20P175      175.0  27.225
# 2386   SPO  TSLA2025-06-20P140      140.0  13.075

# %%
# trade.calc_trade(output='')

# %%
trade.data_table()
# Out:
# Enter number of shares held: 5500
# return           -0.30     -0.25     -0.20     -0.15     -0.10     -0.05  \
# cap_cush     -0.106158 -0.056158 -0.041173 -0.041173 -0.041173 -0.041173
# cap_cush_net -0.118624 -0.068624 -0.053638 -0.053638 -0.053638 -0.053638
# stock        -0.300000 -0.250000 -0.200000 -0.150000 -0.100000 -0.050000
#
# return            0.00      0.05      0.10      0.15      0.20      0.25  \
# cap_cush      0.002595  0.052595  0.102595  0.152595  0.202595  0.252595
# cap_cush_net -0.009870  0.040130  0.090130  0.140130  0.190130  0.240130
# stock         0.000000  0.050000  0.100000  0.150000  0.200000  0.250000
#
# return            0.30
# cap_cush      0.302595
# cap_cush_net  0.290130
# stock         0.300000

# %%
trade.historical_chart()
trade.payoff_plot()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
trade.payoff_plot_plain()
