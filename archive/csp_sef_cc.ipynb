# %%
import csp_sef_cc as sef
import importlib
importlib.reload(sef)
# Out:
# <module 'csp_sef_cc' from 'C:\\Users\\mreis\\OneDrive - Lido Advisors, LLC\\Concentrated Stock\\Lido CSP\\csp_sef_cc.py'>

# %%
trade = sef.SEF_and_CovdCalls(RIC='TSLA.O',get_data='y',expiry='2025-06-20',tgt=-12.5,tgt_yld=0,spy_risk=10,exclude_div='y',custom_div='n',xsp='n')
# Out:
# Enter number of shares held: 5500

# %%
trade.calc_strategy(output='line')
# Out:
#   Underlying Asset  Asset Price  Minimum ($) Expiration Date  Months Left  \
# 0             TSLA       183.01      18300.0      2025-06-20         12.0
#
#     Trade Cost Potential Upside (%) Annual Potential Upside (%)  \
# 0  0.33% Debit               36.28%                      36.38%
#
#   Potential Downside (%) Annual Potential Downside (%) Spread (%)  \
# 0                -12.90%                       -12.94%     49.18%
#
#   Constructive Sale Exclude Div.
# 0              PASS            y

# %%
trade.SEF_payoff_plots()
# Out:
# Enter synthetic replacement percentage: 100
# return           -0.30     -0.25     -0.20     -0.15     -0.10     -0.05  \
# collar       -0.129009 -0.129009 -0.129009 -0.129009 -0.103279 -0.053279
# collar (net) -0.141475 -0.141475 -0.141475 -0.141475 -0.115744 -0.065744
# stock        -0.300000 -0.250000 -0.200000 -0.150000 -0.100000 -0.050000
#
# return            0.00      0.05      0.10      0.15      0.20      0.25  \
# collar       -0.003279  0.046721  0.096721  0.146721  0.196721  0.246721
# collar (net) -0.015744  0.034256  0.084256  0.134256  0.184256  0.234256
# stock         0.000000  0.050000  0.100000  0.150000  0.200000  0.250000
#
# return            0.30
# collar        0.296721
# collar (net)  0.284256
# stock         0.300000
# Concentrated Stock Value: $1,006,555
# TSLA Last: $183.01
# SPY Last: $544.51

# %%
trade.covered_calls()
trade.Covd_Call_plots()
# Out:
# Enter Expiration for Covered Calls: 2024-09-20
# Enter Covered Call Strike Price: 250
# Enter Concentrated Stock Cost Basis: 25
# **************
# Trade Details:
#      Trans              Symbol STRIKE_PRC    MID
# 1469   SCO  TSLA2024-09-20C250      250.0  3.275
#   Instrument  CF_LAST  YIELD  Min_Shares  Min_Cost
# 0     TSLA.O   183.01      0         100   18301.0
# **************
# return               -0.30     -0.25     -0.20     -0.15     -0.10     -0.05  \
# covered_call     -0.282105 -0.232105 -0.182105 -0.132105 -0.082105 -0.032105
# covered_call_net -0.285221 -0.235221 -0.185221 -0.135221 -0.085221 -0.035221
# stock            -0.300000 -0.250000 -0.200000 -0.150000 -0.100000 -0.050000
#
# return                0.00      0.05      0.10      0.15      0.20      0.25  \
# covered_call      0.017895  0.067895  0.117895  0.167895  0.217895  0.267895
# covered_call_net  0.014779  0.064779  0.114779  0.164779  0.214779  0.264779
# ...

# %%
trade.historical_chart()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
trade.ratio_chart()

# %%
trade.relative_perf_chart()
